# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.drop(2,inplace=True)

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                         Ticket     Fare Cabin  \
# Name
# Braund, Mr. Owen Harris                              A/5 21171   7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    PC 17599  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  53.1000  C123
# Allen, Mr. William Henry                                373450   8.0500   NaN
# Moran, Mr. James                                        330877   8.4583   NaN
# ...                                                        ...      ...   ...
# Montvila, Rev. Juozas                                   211536  13.0000   NaN
# Graham, Miss. Margaret Edith                            112053  30.0000   B42
# Johnston, Miss. Catherine Helen "Carrie"            W./C. 6607  23.4500   NaN
# Behr, Mr. Karl Howell                                   111369  30.0000  C148
# Dooley, Mr. Patrick                                     370376   7.7500   NaN
#
#                                                    Embarked
# Name
# Braund, Mr. Owen Harris                                   S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# Allen, Mr. William Henry                                  S
# Moran, Mr. James                                          Q
# ...                                                     ...
# Montvila, Rev. Juozas                                     S
# Graham, Miss. Margaret Edith                              S
# Johnston, Miss. Catherine Helen "Carrie"                  S
# Behr, Mr. Karl Howell                                     C
# Dooley, Mr. Patrick                                       Q
#
# [890 rows x 10 columns]

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
d={'key1':[1,2,3,4],
   'key2':[5,6,7,8]

}
pd.DataFrame(d)
# Out:
#    key1  key2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
df1=pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna('abc')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       abc                   abc
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                         Ticket     Fare Cabin  \
# Name
# Braund, Mr. Owen Harris                              A/5 21171   7.2500   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    PC 17599  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803  53.1000  C123
# Allen, Mr. William Henry                                373450   8.0500   NaN
# Moran, Mr. James                                        330877   8.4583   NaN
# ...                                                        ...      ...   ...
# Montvila, Rev. Juozas                                   211536  13.0000   NaN
# Graham, Miss. Margaret Edith                            112053  30.0000   B42
# Johnston, Miss. Catherine Helen "Carrie"            W./C. 6607  23.4500   NaN
# Behr, Mr. Karl Howell                                   111369  30.0000  C148
# Dooley, Mr. Patrick                                     370376   7.7500   NaN
#
#                                                    Embarked
# Name
# Braund, Mr. Owen Harris                                   S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        C
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              S
# Allen, Mr. William Henry                                  S
# Moran, Mr. James                                          Q
# ...                                                     ...
# Montvila, Rev. Juozas                                     S
# Graham, Miss. Margaret Edith                              S
# Johnston, Miss. Catherine Helen "Carrie"                  S
# Behr, Mr. Karl Howell                                     C
# Dooley, Mr. Patrick                                       Q
#
# [890 rows x 10 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
g=df.groupby('Survived')

# %%
g.sum()
# Out:
# /tmp/ipykernel_80/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            664   8193.67    162    159  16543.3044

# %%
g.mean()
# Out:
# /tmp/ipykernel_80/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.947214  28.351799  0.475073  0.466276  48.514089

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_80/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            136  7111.42     90     77  18177.4125
# 2             87  5168.83     74     70   3801.8417
# 3            118  8898.92    302    193   6706.7701

# %%
g1.max()
# Out:
# /tmp/ipykernel_80/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
g1.max().T
# Out:
# /tmp/ipykernel_80/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# Age                              74.0
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df3=df[['Name','Survived','Pclass']][0:4]

# %%
df3
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3

# %%
df4=df[['Name','Survived','Pclass']][5:10]

# %%
df4
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df3,df4])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df5=pd.concat([df3,df4],axis=1)

# %%
df5.fillna('xyz')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 5                                                xyz      xyz    xyz
# 6                                                xyz      xyz    xyz
# 7                                                xyz      xyz    xyz
# 8                                                xyz      xyz    xyz
# 9                                                xyz      xyz    xyz
#
#                                                 Name Survived Pclass
# 0                                                xyz      xyz    xyz
# 1                                                xyz      xyz    xyz
# 2                                                xyz      xyz    xyz
# 3                                                xyz      xyz    xyz
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1=pd.DataFrame({'key1':[1,2,3,4],
                    'key2':[2,3,4,5],
                    'key3':[3,4,5,6]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     2     3
# 1     2     3     4
# 2     3     4     5
# 3     4     5     6

# %%
data2=pd.DataFrame({'key1':[1,2,23,4],
                    'key4':[23,3,45,5],
                    'key5':[33,4,53,6]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    23    33
# 1     2     3     4
# 2    23    45    53
# 3     4     5     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3    23    33
# 1     2     3     4     3     4
# 2     4     5     6     5     6

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3  23.0  33.0
# 1     2     3     4   3.0   4.0
# 2     3     4     5   NaN   NaN
# 3     4     5     6   5.0   6.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   2.0   3.0    23    33
# 1     2   3.0   4.0     3     4
# 2    23   NaN   NaN    45    53
# 3     4   5.0   6.0     5     6

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   2.0   3.0  23.0  33.0
# 1     2   3.0   4.0   3.0   4.0
# 2     3   4.0   5.0   NaN   NaN
# 3     4   5.0   6.0   5.0   6.0
# 4    23   NaN   NaN  45.0  53.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     2     3       1    23    33
# 1        1     2     3       2     3     4
# 2        1     2     3      23    45    53
# 3        1     2     3       4     5     6
# 4        2     3     4       1    23    33
# 5        2     3     4       2     3     4
# 6        2     3     4      23    45    53
# 7        2     3     4       4     5     6
# 8        3     4     5       1    23    33
# 9        3     4     5       2     3     4
# 10       3     4     5      23    45    53
# 11       3     4     5       4     5     6
# 12       4     5     6       1    23    33
# 13       4     5     6       2     3     4
# 14       4     5     6      23    45    53
# 15       4     5     6       4     5     6

# %%
data1=pd.DataFrame({'key1':[1,2,3,4],
                    'key2':[2,3,4,5],
                    'key3':[3,4,5,6]},
                    index=['a','b','c','d']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     2     3
# b     2     3     4
# c     3     4     5
# d     4     5     6

# %%
data2=pd.DataFrame({'key4':[1,2,23,4],
                    'key5':[23,3,45,5],
                    'key6':[33,4,53,6]},
                   index=['a','b','e','f']
                  )

# %%
data2
# Out:
#    key4  key5  key6
# a     1    23    33
# b     2     3     4
# e    23    45    53
# f     4     5     6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     2     3   1.0  23.0  33.0
# b     2     3     4   2.0   3.0   4.0
# c     3     4     5   NaN   NaN   NaN
# d     4     5     6   NaN   NaN   NaN

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   2.0   3.0     1    23    33
# b   2.0   3.0   4.0     2     3     4
# e   NaN   NaN   NaN    23    45    53
# f   NaN   NaN   NaN     4     5     6

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   2.0   3.0   1.0  23.0  33.0
# b   2.0   3.0   4.0   2.0   3.0   4.0
# c   3.0   4.0   5.0   NaN   NaN   NaN
# d   4.0   5.0   6.0   NaN   NaN   NaN
# e   NaN   NaN   NaN  23.0  45.0  53.0
# f   NaN   NaN   NaN   4.0   5.0   6.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key4  key5  key6
# 0      1     2     3     1    23    33
# 1      1     2     3     2     3     4
# 2      1     2     3    23    45    53
# 3      1     2     3     4     5     6
# 4      2     3     4     1    23    33
# 5      2     3     4     2     3     4
# 6      2     3     4    23    45    53
# 7      2     3     4     4     5     6
# 8      3     4     5     1    23    33
# 9      3     4     5     2     3     4
# 10     3     4     5    23    45    53
# 11     3     4     5     4     5     6
# 12     4     5     6     1    23    33
# 13     4     5     6     2     3     4
# 14     4     5     6    23    45    53
# 15     4     5     6     4     5     6

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C
# 2    female  35.0      1      0      113803  53.1000  C123        S
# 3      male  35.0      0      0      373450   8.0500   NaN        S
# 4      male   NaN      0      0      330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S
# 886  female  19.0      0      0      112053  30.0000   B42        S
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0      111369  30.0000  C148        C
# 889    male  32.0      0      0      370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df['Fare_INR']=df['Fare'].apply(lambda x:x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Fare_INR
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S   580.000
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C  5702.664
# 2  female  35.0      1      0     113803  53.1000  C123        S  4248.000
# 3    male  35.0      0      0     373450   8.0500   NaN        S   644.000
# 4    male   NaN      0      0     330877   8.4583   NaN        Q   676.664

# %%
df['Name_len']=df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Fare_INR  \
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S   580.000
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C  5702.664
# 2  female  35.0      1      0     113803  53.1000  C123        S  4248.000
# 3    male  35.0      0      0     373450   8.0500   NaN        S   644.000
# 4    male   NaN      0      0     330877   8.4583   NaN        Q   676.664
#
#    Name_len
# 0        23
# 1        51
# 2        44
# 3        24
# 4        16

# %%
def cat_fare(x):
    if x<10:
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df['Cat_Fare']=df['Fare'].apply(cat_fare)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Fare_INR  \
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S   580.000
# 1    female  38.0      1      0    PC 17599  71.2833   C85        C  5702.664
# 2    female  35.0      1      0      113803  53.1000  C123        S  4248.000
# 3      male  35.0      0      0      373450   8.0500   NaN        S   644.000
# 4      male   NaN      0      0      330877   8.4583   NaN        Q   676.664
# ..      ...   ...    ...    ...         ...      ...   ...      ...       ...
# 885    male  27.0      0      0      211536  13.0000   NaN        S  1040.000
# 886  female  19.0      0      0      112053  30.0000   B42        S  2400.000
# 887  female   NaN      1      2  W./C. 6607  23.4500   NaN        S  1876.000
# 888    male  26.0      0      0      111369  30.0000  C148        C  2400.000
# 889    male  32.0      0      0      370376   7.7500   NaN        Q   620.000
#
#      Name_len Cat_Fare
# 0          23    cheap
# 1          51     high
# 2          44     high
# 3          24    cheap
# 4          16    cheap
# ..        ...      ...
# 885        21      mid
# 886        28     high
# 887        40     high
# 888        21     high
# 889        19    cheap
#
# [890 rows x 14 columns]
